# %% [markdown]
# Hardware: Physical components of a computer that you can touch
# example: keyboard, mouse, monitor, CPU.
#
# Software: Programs or instructions that run on a computer
# example: Microsoft Word, Browser.
